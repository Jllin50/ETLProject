# %%
import pandas as pd
import csv
from sqlalchemy import create_engine

# %%
baharnmax = "baharnmax.csv"
baharnmax_db = pd.read_csv(baharnmax)

# %%
jack = "economyandcountry.csv"
jack_db = pd.read_csv(jack)

# %%
jack_db
# Out:
#                  countries  Population    GDP Climate
# 0             Afghanistan     31056997    700       1
# 1                 Albania      3581655   4500       3
# 2                 Algeria     32930091   6000       1
# 3                Anguilla        13477   8600       2
# 4       Antigua & Barbuda        69108  11000       2
# 5               Argentina     39921833  11200       3
# 6                 Armenia      2976372   3500       4
# 7                   Aruba        71891  28000       2
# 8               Australia     20264082  29000       1
# 9                 Austria      8192880  30000       3
# 10             Azerbaijan      7961619   3400       1
# 11           Bahamas, The       303770  16700       2
# 12                Bahrain       698585  16900       1
# 13             Bangladesh    147365352   1900       2
# 14               Barbados       279912  15700       2
# 15                Belarus     10293011   6100       4
# ...

# %%
baharnmax_db
# Out:
#      index       Country  Happiness_Score  Rates  Life Expectancy  HDI Rank  \
# 0        0   Afghanistan            3.360    6.4            52.72       168
# 1        1       Albania            4.655    5.6            78.10        68
# 2        2       Algeria            6.355    3.3            76.50        85
# 3        3        Angola            3.866    8.9            60.00       147
# 4        4     Argentina            6.650    9.1            76.70        47
# 5        5       Armenia            4.360    5.7            74.90        83
# 6        6     Australia            7.313   11.7            82.30         3
# 7        7       Austria            7.119   11.4            81.40        20
# 8        8    Azerbaijan            5.291    2.6            73.30        80
# 9        9       Bahrain            6.218    5.7            79.10        43
# 10      10    Bangladesh            4.643    6.1            70.70       136
# ...
